# %% [markdown]
# ## Decon using RedLionFish library
#
# Works fine for small 3D arrays, but takes an extremely long time for large arrays

# %%
import RedLionfishDeconv as rl
from aicsimageio import AICSImage
from skimage.io import imread 
import numpy as np 
import logging
logging.basicConfig(level=logging.INFO)

# %%
psf_1 = imread("../sample_data/psfs/zeiss_simulated/488.tif")
print(psf_1.shape)
# Out:
# (93, 205, 205)

# %%
import napari
napari.view_image(psf_1)
# Out:
# c:\Users\deepu\Anaconda3\envs\napari_lattice\lib\site-packages\napari_tools_menu\__init__.py:194: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, 102.0, 102.0), zoom=1.8907317073170729, angles=(0.0, 0.0, 90.0), perspective=0.0, interactive=True), cursor=Cursor(position=(1.0, 1.0, 0.0), scaled=True, size=1, style=<CursorStyle.STANDARD: 'standard'>), dims=Dims(ndim=3, ndisplay=2, last_used=0, range=((0.0, 93.0, 1.0), (0.0, 205.0, 1.0), (0.0, 205.0, 1.0)), current_step=(46, 102, 102), order=(0, 1, 2), axis_labels=('0', '1', '2')), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False), layers=[<Image layer 'psf_1' at 0x1f1242b5a90>], scale_bar=ScaleBar(visible=False, colored=False, ticks=True, position=<Position.BOTTOM_RIGHT: 'bottom_right'>, font_size=10, unit=None), text_overlay=TextOverlay(visible=False, color=(0.5, 0.5, 0.5, 1.0), font_size=10, position=<TextOverlayPosition.TOP_LEFT: 'top_left'>, text=''), overlays=Overlays(interaction_box=InteractionBox(points=None, show=False, show_handle=False, show_vertices=False, selection_box_drag=None, selection_box_final=None, transform_start=<napari.utils.transforms.transforms.Affine object at 0x000001F11276C3D0>, transform_drag=<napari.utils.transforms.transforms.Affine object at 0x000001F11276C430>, transform_final=<napari.utils.transforms.transforms.Affine object at 0x000001F11276C490>, transform=<napari.utils.transforms.transforms.Affine object at 0x000001F11276C4F0>, allow_new_selection=True, selected_vertex=None)), help='', status='Ready', tooltip=Tooltip(visible=False, text=''), theme='dark', title='napari', mouse_move_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_move at 0x000001F11AB621F0>], mouse_drag_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_drag at 0x000001F11AB4E670>], mouse_double_click_callbacks=[], mouse_wheel_callbacks=[<function dims_scroll at 0x000001F11270DA60>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, keymap={'Shift': <function InteractionBoxMouseBindings.initialize_key_events.<locals>.hold_to_lock_aspect_ratio at 0x000001F11AB4EB80>, 'Control-Shift-R': <function InteractionBoxMouseBindings._reset_active_layer_affine at 0x000001F11A7CB790>, 'Control-Shift-A': <function InteractionBoxMouseBindings._transform_active_layer at 0x000001F11A7CB8B0>})

# %%
psf_binary = psf_1[psf_1>0.0]
psf_binary.min()
# Out:
# 7.488046e-26

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,3, figsize=(15,8))

psf_1_max_xy = np.max(psf_1,axis=0)
psf_1_max_xz = np.max(psf_1,axis=1)
psf_1_max_yz = np.max(psf_1,axis=2)

ax[0].imshow(psf_1_max_xy)
ax[0].set_title("XY")
ax[1].imshow(psf_1_max_xz)
ax[1].set_title("XZ")
ax[2].imshow(psf_1_max_yz)
ax[2].set_title("YZ")
# Out:
# Text(0.5, 1.0, 'YZ')

# %%
fig, ax = plt.subplots(1,3, figsize=(15,8))

psf_1_max_xy = np.max(psf_1,axis=0)
psf_1_max_xz = np.max(psf_1,axis=1)
psf_1_max_yz = np.max(psf_1,axis=2)

ax[0].imshow(psf_1_max_xy)
ax[0].set_title("XY")
ax[1].imshow(psf_1_max_xz)
ax[1].set_title("XZ")
ax[2].imshow(psf_1_max_yz)
ax[2].set_title("YZ")

# %%
psf_binary = psf_1>0.00001


psf_1_max_bin_xy = np.max(psf_binary,axis=0)
psf_1_max_bin_xz = np.max(psf_binary,axis=1)
psf_1_max_bin_yz = np.max(psf_binary,axis=2)


fig, ax = plt.subplots(1,3, figsize=(15,8))
ax[0].imshow(psf_1_max_bin_xy,vmin=0,vmax=1)
ax[0].set_title("XY")
ax[1].imshow(psf_1_max_bin_xz,vmin=0,vmax=1)
ax[1].set_title("XZ")
ax[2].imshow(psf_1_max_bin_yz,vmin=0,vmax=1)
ax[2].set_title("YZ")
# Out:
# Text(0.5, 1.0, 'YZ')

# %%
psf_1.min()
# Out:
# 0.0

# %%
import RedLionfishDeconv.helperfunctions as rlh
test = rlh.change3DSizeTo(psf_1, (50,100,100))
test.shape
# Out:
# (50, 100, 100)

# %%
import napari 
viewer = napari.Viewer()
viewer.add_image(test)
viewer.add_image(psf_1)
viewer.add_image(psf_binary)
# Out:
# c:\Users\deepu\Anaconda3\envs\napari_lattice\lib\site-packages\napari_tools_menu\__init__.py:194: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Image layer 'psf_binary' at 0x1f13aeceaf0>

# %% [markdown]
# ## Trying RL Decon option on a larger dataset.
#
# This can be downloaded from: https://cloudstor.aarnet.edu.au/plus/s/JerHyB7hAIOXiZw

# %%
#Can also optionally generate a numpy array of shape (834,300,2048) for testing purposes
img_large = AICSImage("RBC_full_time_series.czi")

img_large.dask_data
# Out:
# dask.array<transpose, shape=(3, 1, 834, 300, 2048), dtype=uint16, chunksize=(1, 1, 834, 300, 2048), chunktype=numpy.ndarray>

# %%
img_large_data = img_large.data[0,0,...]
print(img_large_data.shape)
# Out:
# (834, 300, 2048)

# %%
img_large_data.dtype

# %%
img_decon_large= rl.doRLDeconvolutionFromNpArrays(data_np = img_large_data, 
                                                    psf_np = psf_1, 
                                                    niter= 10, 
                                                    method = "gpu")
print(img_decon_large.shape)
print(img_large_data.shape)
# Out:
# INFO:root:doRLDeconvolutionFromNpArrays(), niter=10 , method=gpu , useBlockAlgorithm=False, resAsUint8=False
# INFO:root:Reikna package is available
# INFO:root:Trying the OCL non-block RL deconvolution.
# INFO:root:nonBlock_RLDeconvolutionReiknaOCL()
# INFO:root:OCL device selected : <pyopencl.Device 'Quadro P4000' on 'NVIDIA CUDA' at 0x55f933cf9560>
# INFO:root:Device params max_work_item_sizes: [1024, 1024, 64]
# INFO:root:Shape (834, 300, 2048) is too large for OpenCL device shape limits [1024, 1024, 64]. But will try regardless.
# INFO:root:setPSF()
# INFO:root:change3DSizeTo() , shape:(834, 300, 2048)
# INFO:root:nonBlock_RLDeconvolutionReiknaOCL() failed (GPU).
# INFO:root:clEnqueueNDRangeKernel failed: MEM_OBJECT_ALLOCATION_FAILURE
# INFO:root:Trying the OCL block RL deconvolution algorithm.
# INFO:root:block_RLDeconv3DReiknaOCL() , data.shape:(834, 300, 2048), psfdata.shape:(93, 205, 205), max_dim_size:512, psfpaddingfract:1.2
# INFO:root:data shape: (834, 300, 2048) , psf shape: (93, 205, 205)
# INFO:root:blockshape: [512, 300, 512]
# INFO:root:blockstep: [400, 300, 266]
# WARNING:root:Adjusted blockshape is larger than GPU data size limits. Error may occur
# INFO:root:OCL device selected : <pyopencl.Device 'Quadro P4000' on 'NVIDIA CUDA' at 0x55f933cf9560>
# INFO:root:Device params max_work_item_sizes: [1024, 1024, 64]
# INFO:root:Shape [512, 300, 512] is too large for OpenCL device shape limits [1024, 1024, 64]. But will try regardless.
# INFO:root:setPSF()
# INFO:root:change3DSizeTo() , shape:[512, 300, 512]
# INFO:root:Beggining block-by-block iterations.
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,0 , use origin iz00,iy00,ix00 = 0,0,0 , end iz1,iy1,ix1 = 512,300,512
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:Error: block_RLDeconv3DReiknaOCL with blocksize=512 failed (GPU)
# INFO:root:clEnqueueNDRangeKernel failed: MEM_OBJECT_ALLOCATION_FAILURE
# INFO:root:Next it will try to reduce blocksize.
# INFO:root:block_RLDeconv3DReiknaOCL() , data.shape:(834, 300, 2048), psfdata.shape:(93, 205, 205), max_dim_size:448, psfpaddingfract:1.2
# INFO:root:data shape: (834, 300, 2048) , psf shape: (93, 205, 205)
# INFO:root:blockshape: [448, 300, 448]
# INFO:root:blockstep: [336, 300, 202]
# INFO:root:OCL device selected : <pyopencl.Device 'Quadro P4000' on 'NVIDIA CUDA' at 0x55f933cf9560>
# INFO:root:Device params max_work_item_sizes: [1024, 1024, 64]
# INFO:root:setPSF()
# INFO:root:change3DSizeTo() , shape:[448, 300, 448]
# INFO:root:Beggining block-by-block iterations.
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,0 , use origin iz00,iy00,ix00 = 0,0,0 , end iz1,iy1,ix1 = 448,300,448
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,0
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,202 , use origin iz00,iy00,ix00 = 0,0,202 , end iz1,iy1,ix1 = 448,300,650
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,404 , use origin iz00,iy00,ix00 = 0,0,404 , end iz1,iy1,ix1 = 448,300,852
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,606 , use origin iz00,iy00,ix00 = 0,0,606 , end iz1,iy1,ix1 = 448,300,1054
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,808 , use origin iz00,iy00,ix00 = 0,0,808 , end iz1,iy1,ix1 = 448,300,1256
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,1010 , use origin iz00,iy00,ix00 = 0,0,1010 , end iz1,iy1,ix1 = 448,300,1458
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,1212 , use origin iz00,iy00,ix00 = 0,0,1212 , end iz1,iy1,ix1 = 448,300,1660
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,1414 , use origin iz00,iy00,ix00 = 0,0,1414 , end iz1,iy1,ix1 = 448,300,1862
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,1616 , use origin iz00,iy00,ix00 = 0,0,1600 , end iz1,iy1,ix1 = 448,300,2048
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,1818 , use origin iz00,iy00,ix00 = 0,0,1600 , end iz1,iy1,ix1 = 448,300,2048
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 0,0,2020 , use origin iz00,iy00,ix00 = 0,0,1600 , end iz1,iy1,ix1 = 448,300,2048
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 0,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,0 , use origin iz00,iy00,ix00 = 336,0,0 , end iz1,iy1,ix1 = 784,300,448
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,0
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,202 , use origin iz00,iy00,ix00 = 336,0,202 , end iz1,iy1,ix1 = 784,300,650
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,404 , use origin iz00,iy00,ix00 = 336,0,404 , end iz1,iy1,ix1 = 784,300,852
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,606 , use origin iz00,iy00,ix00 = 336,0,606 , end iz1,iy1,ix1 = 784,300,1054
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,808 , use origin iz00,iy00,ix00 = 336,0,808 , end iz1,iy1,ix1 = 784,300,1256
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,1010 , use origin iz00,iy00,ix00 = 336,0,1010 , end iz1,iy1,ix1 = 784,300,1458
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,1212 , use origin iz00,iy00,ix00 = 336,0,1212 , end iz1,iy1,ix1 = 784,300,1660
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,1414 , use origin iz00,iy00,ix00 = 336,0,1414 , end iz1,iy1,ix1 = 784,300,1862
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,1616 , use origin iz00,iy00,ix00 = 336,0,1600 , end iz1,iy1,ix1 = 784,300,2048
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,1818 , use origin iz00,iy00,ix00 = 336,0,1600 , end iz1,iy1,ix1 = 784,300,2048
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 336,0,2020 , use origin iz00,iy00,ix00 = 336,0,1600 , end iz1,iy1,ix1 = 784,300,2048
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,0 , use origin iz00,iy00,ix00 = 386,0,0 , end iz1,iy1,ix1 = 834,300,448
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,0
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,202 , use origin iz00,iy00,ix00 = 386,0,202 , end iz1,iy1,ix1 = 834,300,650
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,404 , use origin iz00,iy00,ix00 = 386,0,404 , end iz1,iy1,ix1 = 834,300,852
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,606 , use origin iz00,iy00,ix00 = 386,0,606 , end iz1,iy1,ix1 = 834,300,1054
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,808 , use origin iz00,iy00,ix00 = 386,0,808 , end iz1,iy1,ix1 = 834,300,1256
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,1010 , use origin iz00,iy00,ix00 = 386,0,1010 , end iz1,iy1,ix1 = 834,300,1458
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,1212 , use origin iz00,iy00,ix00 = 386,0,1212 , end iz1,iy1,ix1 = 834,300,1660
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,1414 , use origin iz00,iy00,ix00 = 386,0,1414 , end iz1,iy1,ix1 = 834,300,1862
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,1616 , use origin iz00,iy00,ix00 = 386,0,1600 , end iz1,iy1,ix1 = 834,300,2048
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,1818 , use origin iz00,iy00,ix00 = 386,0,1600 , end iz1,iy1,ix1 = 834,300,2048
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:New block, intended origin iz0,iy0,ix0 = 672,0,2020 , use origin iz00,iy00,ix00 = 386,0,1600 , end iz1,iy1,ix1 = 834,300,2048
# INFO:root:Start RL deconvolution of this block
# INFO:root:doRLDeconvolution()
# INFO:root:RL completed, result collected
# INFO:root:Clearing GPU RAM
# INFO:root:This block's RL deconvolution completed
# INFO:root:Crop block result from origin jz0,jy0,jx0 = : 56,0,123
# INFO:root:Copying cropped block to datares
# INFO:root:Completed block RL deconvolution.
# (834, 300, 2048)
# (834, 300, 2048)

# %%
import napari
NV = napari.view_image(img_large_data, ndisplay=3)
NV.add_image(img_decon_large)
# Out:
# <Image layer 'img_decon_large' at 0x7f592df818e0>
# WARNING: Unsubstituted placeholders in code: ['$sample', '$sample', '$sample', '$sample', '$sample', '$sample', '$sample']
#   replacements made: ['viewtransformf', 'raycasting_setup', 'before_loop', 'in_loop', 'after_loop', 'sampler_type', 'post', 'pre', 'clip_with_planes', 'cmap', 'get_data']
# WARNING:vispy:Unsubstituted placeholders in code: ['$sample', '$sample', '$sample', '$sample', '$sample', '$sample', '$sample']
#   replacements made: ['viewtransformf', 'raycasting_setup', 'before_loop', 'in_loop', 'after_loop', 'sampler_type', 'post', 'pre', 'clip_with_planes', 'cmap', 'get_data']
# WARNING: Error drawing visual <Volume at 0x7f594a84bbe0>
# WARNING:vispy:Error drawing visual <Volume at 0x7f594a84bbe0>
# Traceback (most recent call last):
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/app/backends/_qt.py", line 903, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 218, in on_draw
#     self._draw_scene()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 277, in _draw_scene
#     self.draw_visual(self.scene)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 315, in draw_visual
#     node.draw()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/visuals.py", line 103, in draw
#     self._visual_superclass.draw(self)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/visual.py", line 451, in draw
#     self._program.draw(self._vshare.draw_mode,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/shaders/program.py", line 102, in draw
#     Program.draw(self, *args, **kwargs)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/program.py", line 526, in draw
#     canvas.context.flush_commands()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/context.py", line 172, in flush_commands
#     self.glir.flush(self.shared.parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 582, in flush
#     self._shared.flush(parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 504, in flush
#     parser.parse(self._filter(self.clear(), parser))
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 822, in parse
#     self._parse(command)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 792, in _parse
#     ob.set_data(*args)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 931, in set_data
#     raise RuntimeError("Shader compilation error in %s:\n%s" %
# RuntimeError: Shader compilation error in GL_FRAGMENT_SHADER:
#     on line 329: error: syntax error, unexpected $undefined
#       vec4 color0 = $sample(u_volumetex, loc);
# WARNING: Error drawing visual <Volume at 0x7f594a84bbe0>
# WARNING:vispy:Error drawing visual <Volume at 0x7f594a84bbe0>
# Traceback (most recent call last):
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/app/backends/_qt.py", line 903, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 218, in on_draw
#     self._draw_scene()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 277, in _draw_scene
#     self.draw_visual(self.scene)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 315, in draw_visual
#     node.draw()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/visuals.py", line 103, in draw
#     self._visual_superclass.draw(self)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/visual.py", line 451, in draw
#     self._program.draw(self._vshare.draw_mode,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/shaders/program.py", line 102, in draw
#     Program.draw(self, *args, **kwargs)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/program.py", line 526, in draw
#     canvas.context.flush_commands()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/context.py", line 172, in flush_commands
#     self.glir.flush(self.shared.parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 582, in flush
#     self._shared.flush(parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 504, in flush
#     parser.parse(self._filter(self.clear(), parser))
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 822, in parse
#     self._parse(command)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 778, in _parse
#     raise RuntimeError('Cannot %s object %i because it '
# RuntimeError: Cannot SIZE object 560 because it does not exist
# WARNING: Error drawing visual <Volume at 0x7f594a84bbe0>
# WARNING:vispy:Error drawing visual <Volume at 0x7f594a84bbe0>
# Traceback (most recent call last):
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/app/backends/_qt.py", line 903, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 218, in on_draw
#     self._draw_scene()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 277, in _draw_scene
#     self.draw_visual(self.scene)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 315, in draw_visual
#     node.draw()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/visuals.py", line 103, in draw
#     self._visual_superclass.draw(self)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/visual.py", line 451, in draw
#     self._program.draw(self._vshare.draw_mode,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/shaders/program.py", line 102, in draw
#     Program.draw(self, *args, **kwargs)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/program.py", line 526, in draw
#     canvas.context.flush_commands()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/context.py", line 172, in flush_commands
#     self.glir.flush(self.shared.parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 582, in flush
#     self._shared.flush(parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 504, in flush
#     parser.parse(self._filter(self.clear(), parser))
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 822, in parse
#     self._parse(command)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 778, in _parse
#     raise RuntimeError('Cannot %s object %i because it '
# RuntimeError: Cannot SIZE object 560 because it does not exist
# WARNING: Error drawing visual <Volume at 0x7f594a84bbe0>
# WARNING:vispy:Error drawing visual <Volume at 0x7f594a84bbe0>
# Traceback (most recent call last):
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/app/backends/_qt.py", line 903, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 218, in on_draw
#     self._draw_scene()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 277, in _draw_scene
#     self.draw_visual(self.scene)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 315, in draw_visual
#     node.draw()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/visuals.py", line 103, in draw
#     self._visual_superclass.draw(self)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/visual.py", line 451, in draw
#     self._program.draw(self._vshare.draw_mode,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/shaders/program.py", line 102, in draw
#     Program.draw(self, *args, **kwargs)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/program.py", line 526, in draw
#     canvas.context.flush_commands()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/context.py", line 172, in flush_commands
#     self.glir.flush(self.shared.parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 582, in flush
#     self._shared.flush(parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 504, in flush
#     parser.parse(self._filter(self.clear(), parser))
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 822, in parse
#     self._parse(command)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 778, in _parse
#     raise RuntimeError('Cannot %s object %i because it '
# RuntimeError: Cannot SIZE object 560 because it does not exist
# WARNING: Error drawing visual <Volume at 0x7f594a84bbe0>
# WARNING:vispy:Error drawing visual <Volume at 0x7f594a84bbe0>
# Traceback (most recent call last):
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/app/backends/_qt.py", line 903, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 218, in on_draw
#     self._draw_scene()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 277, in _draw_scene
#     self.draw_visual(self.scene)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 315, in draw_visual
#     node.draw()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/visuals.py", line 103, in draw
#     self._visual_superclass.draw(self)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/visual.py", line 451, in draw
#     self._program.draw(self._vshare.draw_mode,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/shaders/program.py", line 102, in draw
#     Program.draw(self, *args, **kwargs)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/program.py", line 526, in draw
#     canvas.context.flush_commands()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/context.py", line 172, in flush_commands
#     self.glir.flush(self.shared.parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 582, in flush
#     self._shared.flush(parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 504, in flush
#     parser.parse(self._filter(self.clear(), parser))
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 822, in parse
#     self._parse(command)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 778, in _parse
#     raise RuntimeError('Cannot %s object %i because it '
# RuntimeError: Cannot SIZE object 560 because it does not exist
# WARNING: Unsubstituted placeholders in code: ['$sample', '$sample', '$sample', '$sample', '$sample', '$sample', '$sample']
#   replacements made: ['viewtransformf', 'raycasting_setup', 'before_loop', 'in_loop', 'after_loop', 'sampler_type', 'post', 'pre', 'clip_with_planes', 'cmap', 'get_data']
# WARNING:vispy:Unsubstituted placeholders in code: ['$sample', '$sample', '$sample', '$sample', '$sample', '$sample', '$sample']
#   replacements made: ['viewtransformf', 'raycasting_setup', 'before_loop', 'in_loop', 'after_loop', 'sampler_type', 'post', 'pre', 'clip_with_planes', 'cmap', 'get_data']
# WARNING: Error drawing visual <Volume at 0x7f594a84bbe0>
# WARNING:vispy:Error drawing visual <Volume at 0x7f594a84bbe0>
# Traceback (most recent call last):
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/app/backends/_qt.py", line 903, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 218, in on_draw
#     self._draw_scene()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 277, in _draw_scene
#     self.draw_visual(self.scene)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/canvas.py", line 315, in draw_visual
#     node.draw()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/scene/visuals.py", line 103, in draw
#     self._visual_superclass.draw(self)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/visual.py", line 451, in draw
#     self._program.draw(self._vshare.draw_mode,
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/visuals/shaders/program.py", line 102, in draw
#     Program.draw(self, *args, **kwargs)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/program.py", line 526, in draw
#     canvas.context.flush_commands()
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/context.py", line 172, in flush_commands
#     self.glir.flush(self.shared.parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 582, in flush
#     self._shared.flush(parser)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 504, in flush
#     parser.parse(self._filter(self.clear(), parser))
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 822, in parse
#     self._parse(command)
#   File "/ceph/users/ypu66991/conda_envs/dev/lib/python3.8/site-packages/vispy/gloo/glir.py", line 778, in _parse
#     raise RuntimeError('Cannot %s object %i because it '
# RuntimeError: Cannot SIZE object 560 because it does not exist

# %%
from napari.utils import nbscreenshot
nbscreenshot(NV)

# %%
from napari.utils import nbscreenshot
nbscreenshot(NV)

# %%
import tifffile
tifffile.imsave("RBC_full_time_series_RedLionfish_10iter.tif", img_decon_large, compression='zlib')
